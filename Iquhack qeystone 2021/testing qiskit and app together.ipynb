# %%
import matplotlib
matplotlib.use('agg')
import math
import numpy as np
import sys
import os
sys.path.insert(0, os.path.abspath('./..'))
from jupylet.sprite import Sprite
from jupylet.label import Label
from jupylet.app import App

# %%
app = App()

# %%
from qiskit import *
from math import pi
from qiskit.visualization import plot_bloch_multivector

# %%
qc = QuantumCircuit(1)
qc.x(0)
backend = Aer.get_backend('statevector_simulator')
out = execute(qc,backend).result().get_statevector()
blochpic = plot_bloch_multivector(out)
#print(out)
data = np.fromstring(blochpic.canvas.tostring_rgb(), dtype=np.uint8, sep='')
data = data.reshape(blochpic.canvas.get_width_height()[::-1] + (3,))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-75-6e7825babb6b> in <module>
#       5 blochpic = plot_bloch_multivector(out)
#       6 #print(out)
# ----> 7 data = np.fromstring(blochpic.canvas.tostring_rgb(), dtype=np.uint8, sep='')
#       8 data = data.reshape(blochpic.canvas.get_width_height()[::-1] + (3,))
#
# ~\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in tostring_rgb(self)
#     429         to update the renderer for any subsequent changes to the Figure.
#     430         """
# --> 431         return self.renderer.tostring_rgb()
#     432
#     433     def tostring_argb(self):
#
# AttributeError: 'FigureCanvasAgg' object has no attribute 'renderer'

# %%
#dabloch = Sprite('', x=pp.width-70, y=app.height-70, scale=0.5)

# %%
#@app.run_me_every(1/60)

# %%
@app.event
def blochy():
    dablochy.draw()

# %%
app.run()
# Out:
# Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x08\x06\x0…

# %%
plot_bloch_multivector(out)
